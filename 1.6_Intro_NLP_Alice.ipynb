# %% [markdown]
# # 1.6 Intro to NLP and Network Analysis

# %%
# %pip install spacy
# Out:
# Collecting spacyNote: you may need to restart the kernel to use updated packages.
#
#   Downloading spacy-3.7.4-cp312-cp312-win_amd64.whl.metadata (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.10-cp312-cp312-win_amd64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.8-cp312-cp312-win_amd64.whl.metadata (8.6 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.9-cp312-cp312-win_amd64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.2.2 (from spacy)
#   Downloading thinc-8.2.3-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.4.8-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.4.0,>=0.1.0 (from spacy)
#   Downloading weasel-0.3.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting typer<0.10.0,>=0.3.0 (from spacy)
#   Downloading typer-0.9.4-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<7.0.0,>=5.2.1 (from spacy)
#   Downloading smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (2.32.2)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy)
#   Downloading pydantic-2.7.3-py3-none-any.whl.metadata (108 kB)
#      ---------------------------------------- 0.0/109.0 kB ? eta -:--:--
#      -------------------------------------- 109.0/109.0 kB 6.2 MB/s eta 0:00:00
# Collecting jinja2 (from spacy)
#   Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: setuptools in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (23.2)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Downloading langcodes-3.4.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (1.26.4)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading language_data-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting annotated-types>=0.4.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.18.4 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Downloading pydantic_core-2.18.4-cp312-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.2.2->spacy)
#   Downloading blis-0.7.11-cp312-cp312-win_amd64.whl.metadata (7.6 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.2.2->spacy)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: colorama in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Collecting cloudpathlib<0.17.0,>=0.7.0 (from weasel<0.4.0,>=0.1.0->spacy)
#   Downloading cloudpathlib-0.16.0-py3-none-any.whl.metadata (14 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->spacy)
#   Downloading MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Collecting marisa-trie>=0.7.7 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading marisa_trie-1.1.1-cp312-cp312-win_amd64.whl.metadata (8.9 kB)
# Downloading spacy-3.7.4-cp312-cp312-win_amd64.whl (11.7 MB)
#    ---------------------------------------- 0.0/11.7 MB ? eta -:--:--
#    - -------------------------------------- 0.4/11.7 MB 9.2 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/11.7 MB 10.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.5/11.7 MB 10.7 MB/s eta 0:00:01
#    ------- -------------------------------- 2.2/11.7 MB 11.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.9/11.7 MB 12.4 MB/s eta 0:00:01
#    ------------- -------------------------- 3.9/11.7 MB 13.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.0/11.7 MB 14.6 MB/s eta 0:00:01
#    --------------------- ------------------ 6.2/11.7 MB 15.8 MB/s eta 0:00:01
#    ------------------------ --------------- 7.1/11.7 MB 16.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.2/11.7 MB 17.4 MB/s eta 0:00:01
#    -------------------------------- ------- 9.5/11.7 MB 17.9 MB/s eta 0:00:01
#    ------------------------------------- -- 10.8/11.7 MB 19.8 MB/s eta 0:00:01
#    ---------------------------------------  11.7/11.7 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.7/11.7 MB 19.2 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.8-cp312-cp312-win_amd64.whl (39 kB)
# Downloading langcodes-3.4.0-py3-none-any.whl (182 kB)
#    ---------------------------------------- 0.0/182.0 kB ? eta -:--:--
#    ---------------------------------------- 182.0/182.0 kB ? eta 0:00:00
# Downloading murmurhash-1.0.10-cp312-cp312-win_amd64.whl (25 kB)
# Downloading preshed-3.0.9-cp312-cp312-win_amd64.whl (122 kB)
#    ---------------------------------------- 0.0/122.4 kB ? eta -:--:--
#    ---------------------------------------- 122.4/122.4 kB 7.0 MB/s eta 0:00:00
# Downloading pydantic-2.7.3-py3-none-any.whl (409 kB)
#    ---------------------------------------- 0.0/409.6 kB ? eta -:--:--
#    --------------------------------------- 409.6/409.6 kB 26.6 MB/s eta 0:00:00
# Downloading pydantic_core-2.18.4-cp312-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ------------------------------ --------- 1.4/1.9 MB 30.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 20.4 MB/s eta 0:00:00
# Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.0 kB ? eta -:--:--
#    ---------------------------------------- 57.0/57.0 kB 2.9 MB/s eta 0:00:00
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.4.8-cp312-cp312-win_amd64.whl (478 kB)
#    ---------------------------------------- 0.0/478.8 kB ? eta -:--:--
#    --------------------------------------- 478.8/478.8 kB 29.3 MB/s eta 0:00:00
# Downloading thinc-8.2.3-cp312-cp312-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------- ----------- 1.0/1.4 MB 22.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 22.8 MB/s eta 0:00:00
# Downloading typer-0.9.4-py3-none-any.whl (45 kB)
#    ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#    ---------------------------------------- 46.0/46.0 kB ? eta 0:00:00
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.3.4-py3-none-any.whl (50 kB)
#    ---------------------------------------- 0.0/50.1 kB ? eta -:--:--
#    ---------------------------------------- 50.1/50.1 kB 2.7 MB/s eta 0:00:00
# Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#    ---------------------------------------- 0.0/133.3 kB ? eta -:--:--
#    ---------------------------------------- 133.3/133.3 kB ? eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading blis-0.7.11-cp312-cp312-win_amd64.whl (6.6 MB)
#    ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#    --------- ------------------------------ 1.5/6.6 MB 48.2 MB/s eta 0:00:01
#    ------------------ --------------------- 3.0/6.6 MB 32.0 MB/s eta 0:00:01
#    -------------------------- ------------- 4.4/6.6 MB 31.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.8/6.6 MB 30.9 MB/s eta 0:00:01
#    ---------------------------------------  6.6/6.6 MB 30.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.6/6.6 MB 26.5 MB/s eta 0:00:00
# Downloading cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
#    ---------------------------------------- 0.0/45.0 kB ? eta -:--:--
#    ---------------------------------------- 45.0/45.0 kB 2.3 MB/s eta 0:00:00
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading language_data-1.2.0-py3-none-any.whl (5.4 MB)
#    ---------------------------------------- 0.0/5.4 MB ? eta -:--:--
#    ------ --------------------------------- 0.9/5.4 MB 28.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.3/5.4 MB 29.3 MB/s eta 0:00:01
#    -------------------------- ------------- 3.6/5.4 MB 29.0 MB/s eta 0:00:01
#    ------------------------------------ --- 5.0/5.4 MB 28.9 MB/s eta 0:00:01
#    ---------------------------------------  5.4/5.4 MB 28.7 MB/s eta 0:00:01
#    ---------------------------------------- 5.4/5.4 MB 24.5 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl (17 kB)
# Downloading marisa_trie-1.1.1-cp312-cp312-win_amd64.whl (151 kB)
#    ---------------------------------------- 0.0/151.3 kB ? eta -:--:--
#    ---------------------------------------- 151.3/151.3 kB 8.8 MB/s eta 0:00:00
# Installing collected packages: cymem, wasabi, spacy-loggers, spacy-legacy, smart-open, pydantic-core, murmurhash, MarkupSafe, marisa-trie, cloudpathlib, catalogue, blis, annotated-types, typer, srsly, pydantic, preshed, language-data, jinja2, langcodes, confection, weasel, thinc, spacy
# Successfully installed MarkupSafe-2.1.5 annotated-types-0.7.0 blis-0.7.11 catalogue-2.0.10 cloudpathlib-0.16.0 confection-0.1.5 cymem-2.0.8 jinja2-3.1.4 langcodes-3.4.0 language-data-1.2.0 marisa-trie-1.1.1 murmurhash-1.0.10 preshed-3.0.9 pydantic-2.7.3 pydantic-core-2.18.4 smart-open-6.4.0 spacy-3.7.4 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.3 typer-0.9.4 wasabi-1.1.3 weasel-0.3.4

# %%
# %pip install networkx
# Out:
# Collecting networkxNote: you may need to restart the kernel to use updated packages.
#
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.7 MB 660.6 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/1.7 MB 1.2 MB/s eta 0:00:02
#    ------ --------------------------------- 0.3/1.7 MB 1.7 MB/s eta 0:00:01
#    --------- ------------------------------ 0.4/1.7 MB 2.2 MB/s eta 0:00:01
#    ------------- -------------------------- 0.6/1.7 MB 2.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/1.7 MB 2.5 MB/s eta 0:00:01
#    --------------------- ------------------ 0.9/1.7 MB 2.6 MB/s eta 0:00:01
#    -------------------------- ------------- 1.1/1.7 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.5/1.7 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 3.5 MB/s eta 0:00:00
# Installing collected packages: networkx
# Successfully installed networkx-3.3

# %%
# %pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.13.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.6 kB 330.3 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/60.6 kB 525.1 kB/s eta 0:00:01
#      -------------------------------------- 60.6/60.6 kB 535.5 kB/s eta 0:00:00
# Requirement already satisfied: numpy<2.3,>=1.22.4 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from scipy) (1.26.4)
# Downloading scipy-1.13.1-cp312-cp312-win_amd64.whl (45.9 MB)
#    ---------------------------------------- 0.0/45.9 MB ? eta -:--:--
#    ---------------------------------------- 0.5/45.9 MB 9.8 MB/s eta 0:00:05
#    - -------------------------------------- 1.4/45.9 MB 14.8 MB/s eta 0:00:04
#    -- ------------------------------------- 2.8/45.9 MB 19.8 MB/s eta 0:00:03
#    --- ------------------------------------ 4.1/45.9 MB 20.3 MB/s eta 0:00:03
#    ---- ----------------------------------- 5.7/45.9 MB 22.6 MB/s eta 0:00:02
#    ------ --------------------------------- 7.1/45.9 MB 23.8 MB/s eta 0:00:02
#    ------- -------------------------------- 8.6/45.9 MB 24.9 MB/s eta 0:00:02
#    -------- ------------------------------- 10.1/45.9 MB 25.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 11.6/45.9 MB 28.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 13.1/45.9 MB 29.7 MB/s eta 0:00:02
#    ------------ --------------------------- 14.5/45.9 MB 29.7 MB/s eta 0:00:02
#    ------------- -------------------------- 15.8/45.9 MB 29.7 MB/s eta 0:00:02
#    --------------- ------------------------ 17.3/45.9 MB 29.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 18.7/45.9 MB 28.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 20.1/45.9 MB 28.5 MB/s eta 0:00:01
#    ------------------ --------------------- 21.5/45.9 MB 28.4 MB/s eta 0:00:01
#    ------------------- -------------------- 22.4/45.9 MB 28.5 MB/s eta 0:00:01
#    -------------------- ------------------- 23.5/45.9 MB 26.2 MB/s eta 0:00:01
#    --------------------- ------------------ 25.0/45.9 MB 26.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 26.5/45.9 MB 26.2 MB/s eta 0:00:01
#    ------------------------ --------------- 28.0/45.9 MB 27.3 MB/s eta 0:00:01
#    ------------------------- -------------- 29.3/45.9 MB 26.2 MB/s eta 0:00:01
#    -------------------------- ------------- 30.7/45.9 MB 26.2 MB/s eta 0:00:01
#    --------------------------- ------------ 32.0/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 33.2/45.9 MB 27.3 MB/s eta 0:00:01
#    ------------------------------ --------- 34.5/45.9 MB 27.3 MB/s eta 0:00:01
#    ------------------------------- -------- 35.8/45.9 MB 27.3 MB/s eta 0:00:01
#    -------------------------------- ------- 37.2/45.9 MB 27.3 MB/s eta 0:00:01
#    --------------------------------- ------ 38.5/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 39.8/45.9 MB 26.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 41.1/45.9 MB 26.2 MB/s eta 0:00:01
#    ------------------------------------ --- 42.4/45.9 MB 26.2 MB/s eta 0:00:01
#    ------------------------------------- -- 43.5/45.9 MB 26.2 MB/s eta 0:00:01
#    -------------------------------------- - 44.7/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------- 45.9/45.9 MB 820.1 kB/s eta 0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.13.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install -U spacy
# Out:
# Requirement already satisfied: spacy in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (2.7.3)
# Requirement already satisfied: jinja2 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.1.1)

# %%
# !pip show spacy
# Out:
# Name: spacy
# Version: 3.7.4
# Summary: Industrial-strength Natural Language Processing (NLP) in Python
# Home-page: https://spacy.io
# Author: Explosion
# Author-email: contact@explosion.ai
# License: MIT
# Location: C:\Users\bhimc\anaconda3\envs\venv_alice\Lib\site-packages
# Requires: catalogue, cymem, jinja2, langcodes, murmurhash, numpy, packaging, preshed, pydantic, requests, setuptools, smart-open, spacy-legacy, spacy-loggers, srsly, thinc, tqdm, typer, wasabi, weasel
# Required-by:

# %%
import pandas as pd 
import numpy as np
import spacy
from spacy import displacy
import networkx as nx
import os
import matplotlib.pyplot as plt
import scipy
import re

# %%
# Download English module

# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.7.3)
# Requirement already satisfied: jinja2 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: colorama in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\bhimc\anaconda3\envs\venv_alice\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load spacy English module

NER = spacy.load("en_core_web_sm")

# %% [markdown]
# ## Load Alice in Wonderland Book

# %%
# Load the book

with open('Alice_article_Wiki.txt', 'r', errors='ignore') as file:
    data = file.read().replace('\n', '')

# %%
book = NER(data)

# %%
# Visualize identified entities

displacy.render(book[273:20000], style = "ent", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1992â€“1995)Once
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Upon a Time in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2013â€“2014)**Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# 's
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland Bakery
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2022â€“2024)Theatrical
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  presentationsPlay(s)Alice in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland Jr.GamesVideo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  game(s)Alice in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (2000)Alice in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2010)Disney
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Infinity
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2015)*AudioSoundtrack(s)Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1951)Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  in Wonderland: An Original Walt Disney Records Soundtrack (2010)Alice Through the Looking Glass: Original Motion Picture Soundtrack (2016)Original musicAlmost
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2010)MiscellaneousTheme
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  park attraction(s)Mad
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tea Party
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1955â€“present)Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1958â€“present)Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# 's
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Curious Labyrinth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1992â€“present)Mad
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  T Party (2012â€“2016)* Work where this franchise's characters or settings appeared as part of a crossover.** Spin-off of TV series
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Once Upon a Time
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  (
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2011â€“2018)Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>

# %% [markdown]
# ## Get named entity list per sentence

# %%
df_sentences = [] # empty shell to store results

# Loop through sentences, get entity list for each sentence
for sent in book.sents:
    entity_list = [ent.text for ent in sent.ents]
    df_sentences.append({"sentence": sent, "entities": entity_list})
    
df_sentences = pd.DataFrame(df_sentences)

# %%
df_sentences.head(10)
# Out:
#                                             sentence  \
# 0  (Alice, in, Wonderland, (, franchise, ), -, Wi...
# 1  (Logo, used, for, the, 2010, live, -, action, ...
# 2  (Work, where, this, franchise, 's, characters,...
# 3  (*, *, Spin, -, off, of, TV, series, Once, Upo...
# 4  (The, film, is, an, adaptation, of, the, books...
# 5  (A, live, -, action, film, directed, by, Tim, ...
# 6  (Alice, in, Wonderland, (, 1951, film)Alice, i...
# 7  (The, film, was, released, in, New, York, City...
# 8  (The, theme, song, ,, ", Alice, in, Wonderland...
# 9  (Live, -, action, films[edit]Alice, in, Wonder...
#
#                                             entities
# 0  [Alice, Wonderland, Navigation\tMain, Contribu...
# 1  [Logo, 2010, Wonderland, Walt Disney CompanyBa...
# 2                                                 []
# 3  [Once Upon a Time, 2011â€“2018)Alice, Wonderla...
# 4  [Lewis Carroll, 1865, Alice, Wonderland, 1871,...
# 5  [Tim Burton, 2010.Films[edit]FilmU.S., Wonderl...
# 6  [Alice, Wonderland, 1951, Wonderland, 1951, Am...
# 7  [New York City, London, July 26, 1951, Kathryn...
# 8                                [Alice, Wonderland]
# 9                             [Wonderland[edit]Main]

# %% [markdown]
# ## Load Character names

# %%
# Import characters

character_df = pd.read_csv("characters_alice.csv", index_col = 0)

# %%
character_df.head()
# Out:
#           character character_alias
# 0             Alice           Alice
# 1  The White Rabbit          Rabbit
# 2         The Mouse           Mouse
# 3          The Dodo            Dodo
# 4          The Lory            Lory

# %% [markdown]
# ## Filtering entities from the book

# %%
# Function to filter out entities not of interest

def filter_entity(ent_list, character_df):
    return [ent for ent in ent_list 
            if ent in list(character_df['character_alias'])]

# %%
# Check

filter_entity(["Alice", "CF", "2"], character_df)
# Out:
# ['Alice']

# %%
df_sentences['character_entities'] = df_sentences['entities'].apply(lambda x: filter_entity(x, character_df))

# %%
df_sentences['character_entities'].head(20)
# Out:
# 0     [Alice, Alice]
# 1            [Alice]
# 2                 []
# 3     [Alice, Alice]
# 4     [Alice, Alice]
# 5                 []
# 6     [Alice, Alice]
# 7            [Alice]
# 8            [Alice]
# 9                 []
# 10           [Alice]
# 11                []
# 12                []
# 13                []
# 14                []
# 15           [Alice]
# 16           [Alice]
# 17           [Alice]
# 18                []
# 19                []
# Name: character_entities, dtype: object

# %%
# Filter out sentences that don't have any character entities

df_sentences_filtered = df_sentences[df_sentences['character_entities'].map(len) > 0]

# %%
df_sentences_filtered.tail(10)
# Out:
#                                              sentence  \
# 39  (Alice, 's, Curious, Labyrinth[edit]Main, arti...
# 42  (The, ride, theme, is, inspired, by, the, Unbi...
# 44  (Alice, in, Wonderland, (, ride)[edit]Main, ar...
# 49  (The, show, is, inspired, by, Tim, Burton, 's,...
# 55  (Almost, AliceAlmost, Alice, is, a, concept, a...
# 63  (October, 20, ,, 2017.vteDisney, 's, Alice, in...
# 68  (Doth, the, Little, Crocodile""The, Mouse, 's,...
# 71  (No, More, ", (, 1985, music, video)Alice, in,...
# 72  (Through, the, Looking, Glass, (, 2016)"Just, ...
# 84  (Alice, in, Wonderland, (, franchise)Walt, Dis...
#
#                                              entities  \
# 39  [Alice, Alice, Curious Labyrinth, Disneyland P...
# 42              [Unbirthday Party, Alice, Wonderland]
# 44  [Alice, Wonderland, Alice, Wonderland, Disneyl...
# 49                  [Tim Burton's, Alice, Wonderland]
# 55  [Almost AliceAlmost Alice, Burton, Alice, Wond...
# 63  [October 20, Alice, WonderlandWorks, Alice, Wo...
# 68  [Doth the Little Crocodile""The Mouse's, the V...
# 71                          [1985, Wonderland, Alice]
# 72  [2016)"Just, 2020, the Looking Glass, Wonderla...
# 84  [Alice, Wonderland, Disney Studios, Alice, Won...
#
#               character_entities
# 39                [Alice, Alice]
# 42                       [Alice]
# 44                [Alice, Alice]
# 49                       [Alice]
# 55                       [Alice]
# 63                [Alice, Alice]
# 68                       [Alice]
# 71                       [Alice]
# 72  [Alice, Alice, Alice, Alice]
# 84                [Alice, Alice]

# %% [markdown]
# ## Create Relationships

# %%
# Defining relationships 

# window size = 5 : this defines how many sentences will be looked at simultaneously 
relationships = [] # create an empty list

for i in range(df_sentences_filtered.index[-1]):
    end_i = min(i+5, df_sentences_filtered.index[-1])
    char_list = sum((df_sentences_filtered.loc[i: end_i].character_entities), [])
    
    # Remove duplicated characters that are next to each other
    char_unique = [char_list[i] for i in range(len(char_list)) 
                   if (i==0) or char_list[i] != char_list[i-1]]
    
    if len(char_unique) > 1:
        for idx, a in enumerate(char_unique[:-1]):
            b = char_unique[idx + 1]
            relationships.append({"source": a, "target": b})

# %%
relationship_df = pd.DataFrame(relationships)

# %%
relationship_df
# Out:
#          source       target
# 0   Caterpillar        Alice
# 1   Caterpillar        Alice
# 2   Caterpillar        Alice
# 3   Caterpillar        Alice
# 4   Caterpillar        Alice
# 5         Alice  Caterpillar
# 6   Caterpillar        Alice
# 7         Alice  Caterpillar
# 8   Caterpillar        Alice
# 9         Alice  Caterpillar
# 10  Caterpillar        Alice
# 11        Alice  Caterpillar
# 12  Caterpillar        Alice
# 13        Alice  Caterpillar
# 14  Caterpillar        Alice
# 15        Alice  Caterpillar
# 16  Caterpillar        Alice

# %%
# Sort the cases with a->b and b->a

relationship_df = pd.DataFrame(np.sort(relationship_df.values, axis = 1), columns = relationship_df.columns)
relationship_df.head(5)
# Out:
#   source       target
# 0  Alice  Caterpillar
# 1  Alice  Caterpillar
# 2  Alice  Caterpillar
# 3  Alice  Caterpillar
# 4  Alice  Caterpillar

# %%
# Summarize the interactions

relationship_df["value"] = 1
relationship_df = relationship_df.groupby(["source","target"], sort=False, as_index=False).sum()

# %%
relationship_df.head(10)
# Out:
#   source       target  value
# 0  Alice  Caterpillar     17

# %%
relationship_df.tail(10)
# Out:
#   source       target  value
# 0  Alice  Caterpillar     17

# %%
relationship_df.to_csv('alice_relationship.csv')
